#  extracting: data/coco/images/val2017/000000043435.jpg
#  extracting: data/coco/images/val2017/000000546325.jpg
#  extracting: data/coco/images/val2017/000000291619.jpg
#  extracting: data/coco/images/val2017/000000512648.jpg
#  extracting: data/coco/images/val2017/000000014226.jpg
#  extracting: data/coco/images/val2017/000000084492.jpg
#  extracting: data/coco/images/val2017/000000376478.jpg
#  extracting: data/coco/images/val2017/000000124636.jpg
#  extracting: data/coco/images/val2017/000000564091.jpg
#  extracting: data/coco/images/val2017/000000477689.jpg
#  extracting: data/coco/images/val2017/000000523957.jpg
#  extracting: data/coco/images/val2017/000000570539.jpg
#  extracting: data/coco/images/val2017/000000470121.jpg
#  extracting: data/coco/images/val2017/000000199442.jpg
#  extracting: data/coco/images/val2017/000000563653.jpg
#  extracting: data/coco/images/val2017/000000181421.jpg
#  extracting: data/coco/images/val2017/000000302990.jpg
#  extracting: data/coco/images/val2017/000000446005.jpg
#  extracting: data/coco/images/val2017/000000329219.jpg
#  extracting: data/coco/images/val2017/000000388258.jpg
#  extracting: data/coco/images/val2017/000000126137.jpg
#  extracting: data/coco/images/val2017/000000500826.jpg

# %%
import torch
import torchvision
from torchvision.models.detection import maskrcnn_resnet50_fpn
from ultralytics import YOLO
from PIL import Image
import numpy as np
from pycocotools.coco import COCO
from pycocotools import mask as maskUtils
import time
import cv2
import matplotlib.pyplot as plt
import psutil
import os

# %%
NUM_IMAGES = 1000
CONFIDENCE_THRESHOLD = 0.5

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load Mask R-CNN
maskrcnn_model = maskrcnn_resnet50_fpn(pretrained=True).to(device).eval()

# Load YOLOv8-seg
yolov8_model = YOLO('yolov8x-seg.pt').to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from PIL import Image
from torchvision.transforms import functional as F
import torch
import numpy as np
from pycocotools import mask as maskUtils
import time
import cv2

def evaluate_model(model, coco, img_ids, model_type='maskrcnn'):
    """Evaluate model on COCO dataset"""
    metrics = []

    for img_id in img_ids[:NUM_IMAGES]:  # Evaluate on first 50 images
        # Load image and annotations
        img_info = coco.loadImgs(img_id)[0]
        img_path = f"data/coco/images/val2017/{img_info['file_name']}"
        ann_ids = coco.getAnnIds(imgIds=img_id)
        annotations = coco.loadAnns(ann_ids)

        # Get ground truth
        gt_masks = [coco.annToMask(ann) for ann in annotations]
        gt_boxes = [ann['bbox'] for ann in annotations]

        # Get image dimensions
        img = Image.open(img_path)
        img_width, img_height = img.size

        # Run inference
        start_time = time.time()

        if model_type == 'maskrcnn':
            # Mask R-CNN inference
            image_tensor = F.to_tensor(img).unsqueeze(0).to(device)
            with torch.no_grad():
                outputs = model(image_tensor)[0]

            # Process Mask R-CNN outputs
            pred_masks = outputs['masks'].cpu().numpy().squeeze(1)
            scores = outputs['scores'].cpu().numpy()
            keep = scores > CONFIDENCE_THRESHOLD  # Confidence threshold
            pred_masks = pred_masks[keep]
            pred_boxes = outputs['boxes'].cpu().numpy()[keep]

        else:  # YOLOv8
            # YOLOv8 inference
            try:
                results = model(img_path)
                result = results[0]  # Get first (and only) result

                # Process YOLOv8 outputs
                if result.masks is None:  # No detections
                    pred_masks = np.zeros((0, img_height, img_width))
                    pred_boxes = np.zeros((0, 4))
                else:
                    pred_masks = result.masks.data.cpu().numpy()
                    pred_boxes = result.boxes.xyxy.cpu().numpy()

                    # Resize masks to original image dimensions
                    resized_masks = []
                    for mask in pred_masks:
                        mask = cv2.resize(mask.squeeze(), (img_width, img_height))
                        resized_masks.append(mask)
                    pred_masks = np.array(resized_masks)

            except Exception as e:
                print(f"Error processing image {img_id}: {str(e)}")
                pred_masks = np.zeros((0, img_height, img_width))
                pred_boxes = np.zeros((0, 4))

        inference_time = time.time() - start_time

        # Calculate metrics if we have predictions
        if len(pred_boxes) > 0:
            # Convert masks to RLE format for pycocotools
            pred_rles = [maskUtils.encode(np.asarray(mask > 0.5, order='F'))
                        for mask in pred_masks]
            gt_rles = [maskUtils.encode(np.asarray(mask, order='F'))
                      for mask in gt_masks]

            # Calculate IoU
            ious = maskUtils.iou(pred_rles, gt_rles, [0]*len(gt_rles))
            miou = np.mean(ious) if len(ious) > 0 else 0

            # Calculate mAP (simplified version)
            tp = np.sum(np.max(ious, axis=1) > 0.5) if len(ious) > 0 else 0
            precision = tp / len(pred_boxes)

        else:
            miou = 0
            precision = 0

        metric = {
            'mAP': precision,
            'mIoU': miou,
            'Dice': 2 * miou / (1 + miou) if miou > 0 else 0,
            'FPS': 1 / (inference_time + 1e-6)  # Avoid division by zero
        }

        print("Metric for:", img_path)
        print(metric)
        metrics.append(metric)

    # Aggregate metrics
    return {
        'mAP': np.mean([r['mAP'] for r in metrics]),
        'mIoU': np.mean([r['mIoU'] for r in metrics]),
        'Dice': np.mean([r['Dice'] for r in metrics]),
        'FPS': np.mean([r['FPS'] for r in metrics])
    }

# %%
# Initialize COCO API
coco = COCO('data/coco/annotations/instances_val2017.json')
img_ids = coco.getImgIds()[:NUM_IMAGES]

# Evaluate models
maskrcnn_results = evaluate_model(maskrcnn_model, coco, img_ids, 'maskrcnn')
yolov8_results = evaluate_model(yolov8_model, coco, img_ids, 'yolov8')

# Display results
print("Mask R-CNN Results:", maskrcnn_results)
print("YOLOv8 Results:", yolov8_results)
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 2.0ms preprocess, 45.7ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000397133.jpg
# {'mAP': np.float64(0.4117647058823529), 'mIoU': np.float64(0.017405522619574485), 'Dice': np.float64(0.03421550646739061), 'FPS': 10.877000421551482}
#
# image 1/1 /content/data/coco/images/val2017/000000037777.jpg: 448x640 1 bottle, 1 bowl, 1 banana, 5 oranges, 2 chairs, 1 potted plant, 1 dining table, 1 oven, 1 sink, 1 refrigerator, 45.0ms
# Speed: 2.9ms preprocess, 45.0ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000037777.jpg
# {'mAP': np.float64(0.26666666666666666), 'mIoU': np.float64(0.03709713436467117), 'Dice': np.float64(0.07154032758444943), 'FPS': 14.342384320999303}
#
# image 1/1 /content/data/coco/images/val2017/000000252219.jpg: 448x640 3 persons, 1 car, 2 traffic lights, 1 backpack, 2 umbrellas, 47.1ms
# Speed: 2.1ms preprocess, 47.1ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000252219.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.07645687143908522), 'Dice': np.float64(0.1420528280652288), 'FPS': 14.071955961238366}
#
# image 1/1 /content/data/coco/images/val2017/000000087038.jpg: 480x640 14 persons, 1 bicycle, 2 skateboards, 49.9ms
# Speed: 2.1ms preprocess, 49.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000087038.jpg
# {'mAP': np.float64(0.6470588235294118), 'mIoU': np.float64(0.031209280744752495), 'Dice': np.float64(0.06052947995621752), 'FPS': 12.507459712267249}
#
# image 1/1 /content/data/coco/images/val2017/000000174482.jpg: 416x640 1 bicycle, 9 cars, 1 truck, 43.0ms
# Speed: 1.9ms preprocess, 43.0ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
# Metric for: data/coco/images/val2017/000000174482.jpg
# {'mAP': np.float64(0.45454545454545453), 'mIoU': np.float64(0.03814655430882624), 'Dice': np.float64(0.07348972869100033), 'FPS': 13.55874018640327}
#
# image 1/1 /content/data/coco/images/val2017/000000403385.jpg: 512x640 1 toilet, 1 sink, 50.7ms
# Speed: 2.2ms preprocess, 50.7ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 640)
# Metric for: data/coco/images/val2017/000000403385.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4286888518706154), 'Dice': np.float64(0.6001150653752539), 'FPS': 14.883805736691981}
#
# image 1/1 /content/data/coco/images/val2017/000000006818.jpg: 640x448 1 toilet, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000006818.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.888605658934489), 'Dice': np.float64(0.9410176811985423), 'FPS': 15.046496134273756}
#
# image 1/1 /content/data/coco/images/val2017/000000480985.jpg: 640x480 8 persons, 3 motorcycles, 52.2ms
# Speed: 3.0ms preprocess, 52.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000480985.jpg
# {'mAP': np.float64(0.7272727272727273), 'mIoU': np.float64(0.04324947472214484), 'Dice': np.float64(0.08291300550841638), 'FPS': 13.28963368293801}
#
# image 1/1 /content/data/coco/images/val2017/000000458054.jpg: 448x640 8 toilets, 47.6ms
# Speed: 2.2ms preprocess, 47.6ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000458054.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.06572035610008328), 'Dice': np.float64(0.12333508640218072), 'FPS': 13.9185102077598}
#
# image 1/1 /content/data/coco/images/val2017/000000331352.jpg: 640x480 1 toilet, 1 sink, 50.2ms
# Speed: 4.2ms preprocess, 50.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000331352.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.36794603985452656), 'Dice': np.float64(0.5379540261597681), 'FPS': 14.71060055790864}
#
# image 1/1 /content/data/coco/images/val2017/000000296649.jpg: 448x640 14 persons, 1 bicycle, 5 cars, 2 motorcycles, 47.8ms
# Speed: 1.6ms preprocess, 47.8ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000296649.jpg
# {'mAP': np.float64(0.7272727272727273), 'mIoU': np.float64(0.023704587974216654), 'Dice': np.float64(0.04631138367978807), 'FPS': 12.472794896115277}
#
# image 1/1 /content/data/coco/images/val2017/000000386912.jpg: 480x640 1 person, 1 tv, 1 laptop, 4 books, 47.6ms
# Speed: 1.6ms preprocess, 47.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000386912.jpg
# {'mAP': np.float64(0.2857142857142857), 'mIoU': np.float64(0.018229666810192263), 'Dice': np.float64(0.03580659138974085), 'FPS': 14.236308579961637}
#
# image 1/1 /content/data/coco/images/val2017/000000502136.jpg: 544x640 2 potted plants, 2 vases, 60.8ms
# Speed: 3.9ms preprocess, 60.8ms inference, 2.4ms postprocess per image at shape (1, 3, 544, 640)
# Metric for: data/coco/images/val2017/000000502136.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.19087192950453652), 'Dice': np.float64(0.3205582813324838), 'FPS': 11.732640690091984}
#
# image 1/1 /content/data/coco/images/val2017/000000491497.jpg: 640x480 1 person, 1 chair, 1 bed, 1 tv, 1 book, 50.3ms
# Speed: 3.0ms preprocess, 50.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000491497.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.09102744332491884), 'Dice': np.float64(0.1668655429005739), 'FPS': 14.418559204720149}
#
# image 1/1 /content/data/coco/images/val2017/000000184791.jpg: 512x640 1 bowl, 3 oranges, 51.7ms
# Speed: 2.0ms preprocess, 51.7ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 640)
# Metric for: data/coco/images/val2017/000000184791.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.1273500185482669), 'Dice': np.float64(0.22592809057165855), 'FPS': 14.250529110799562}
#
# image 1/1 /content/data/coco/images/val2017/000000348881.jpg: 480x640 2 persons, 2 airplanes, 1 truck, 1 suitcase, 54.4ms
# Speed: 1.7ms preprocess, 54.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000348881.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.104099566409445), 'Dice': np.float64(0.1885691645509453), 'FPS': 13.282310902789789}
#
# image 1/1 /content/data/coco/images/val2017/000000289393.jpg: 480x640 1 bird, 1 sheep, 1 cow, 2 giraffes, 47.8ms
# Speed: 2.9ms preprocess, 47.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000289393.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.1815782120865343), 'Dice': np.float64(0.3073486126083648), 'FPS': 15.01267460905876}
#
# image 1/1 /content/data/coco/images/val2017/000000522713.jpg: 480x640 5 boats, 2 benchs, 50.4ms
# Speed: 1.7ms preprocess, 50.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000522713.jpg
# {'mAP': np.float64(0.14285714285714285), 'mIoU': np.float64(0.03178080261401634), 'Dice': np.float64(0.06160378741976918), 'FPS': 14.262983274827668}
#
# image 1/1 /content/data/coco/images/val2017/000000181666.jpg: 448x640 3 persons, 18 sheeps, 47.3ms
# Speed: 1.9ms preprocess, 47.3ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000181666.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.031199654251932364), 'Dice': np.float64(0.06051137453991034), 'FPS': 12.141383511255064}
#
# image 1/1 /content/data/coco/images/val2017/000000017627.jpg: 480x640 3 persons, 11 cars, 1 stop sign, 47.9ms
# Speed: 2.3ms preprocess, 47.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000017627.jpg
# {'mAP': np.float64(0.8666666666666667), 'mIoU': np.float64(0.045483253365694816), 'Dice': np.float64(0.08700905197528867), 'FPS': 13.125485675865836}
#
# image 1/1 /content/data/coco/images/val2017/000000143931.jpg: 480x640 1 bus, 46.7ms
# Speed: 2.1ms preprocess, 46.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000143931.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4984532171900417), 'Dice': np.float64(0.6652903293501025), 'FPS': 15.77178405215999}
#
# image 1/1 /content/data/coco/images/val2017/000000303818.jpg: 640x480 12 persons, 3 cars, 1 bus, 1 traffic light, 1 backpack, 3 handbags, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000303818.jpg
# {'mAP': np.float64(0.7619047619047619), 'mIoU': np.float64(0.03310193427440367), 'Dice': np.float64(0.0640826101979041), 'FPS': 11.684105382635526}
#
# image 1/1 /content/data/coco/images/val2017/000000463730.jpg: 448x640 13 persons, 2 cars, 1 motorcycle, 2 buss, 1 truck, 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000463730.jpg
# {'mAP': np.float64(0.7368421052631579), 'mIoU': np.float64(0.02960964984394444), 'Dice': np.float64(0.057516263272070746), 'FPS': 13.037401245149523}
#
# image 1/1 /content/data/coco/images/val2017/000000460347.jpg: 640x448 1 person, 4 cars, 1 bus, 1 truck, 45.4ms
# Speed: 1.9ms preprocess, 45.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000460347.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.10560388066092864), 'Dice': np.float64(0.19103384586132016), 'FPS': 15.140186687414642}
#
# image 1/1 /content/data/coco/images/val2017/000000322864.jpg: 640x448 1 person, 6 cars, 1 truck, 46.6ms
# Speed: 2.1ms preprocess, 46.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000322864.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.09468582178841149), 'Dice': np.float64(0.17299177518115885), 'FPS': 14.477834993868761}
#
# image 1/1 /content/data/coco/images/val2017/000000226111.jpg: 640x480 (no detections), 51.3ms
# Speed: 1.7ms preprocess, 51.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000226111.jpg
# {'mAP': 0, 'mIoU': 0, 'Dice': 0, 'FPS': 16.2802645515465}
#
# image 1/1 /content/data/coco/images/val2017/000000153299.jpg: 640x608 2 giraffes, 71.7ms
# Speed: 4.9ms preprocess, 71.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 608)
# Metric for: data/coco/images/val2017/000000153299.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4146646068798742), 'Dice': np.float64(0.5862373383249353), 'FPS': 11.070936656502912}
#
# image 1/1 /content/data/coco/images/val2017/000000308394.jpg: 448x640 1 person, 1 train, 1 bench, 2 handbags, 1 refrigerator, 49.7ms
# Speed: 2.2ms preprocess, 49.7ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000308394.jpg
# {'mAP': np.float64(0.3333333333333333), 'mIoU': np.float64(0.10435613808531957), 'Dice': np.float64(0.1889900087235397), 'FPS': 14.043497802863419}
#
# image 1/1 /content/data/coco/images/val2017/000000456496.jpg: 448x640 1 person, 5 birds, 46.5ms
# Speed: 2.1ms preprocess, 46.5ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000456496.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.09030772457249583), 'Dice': np.float64(0.16565547970946465), 'FPS': 15.046280228323885}
#
# image 1/1 /content/data/coco/images/val2017/000000058636.jpg: 640x640 (no detections), 69.9ms
# Speed: 2.2ms preprocess, 69.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Metric for: data/coco/images/val2017/000000058636.jpg
# {'mAP': 0, 'mIoU': 0, 'Dice': 0, 'FPS': 11.89461147866387}
#
# image 1/1 /content/data/coco/images/val2017/000000041888.jpg: 480x640 3 birds, 54.6ms
# Speed: 2.1ms preprocess, 54.6ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000041888.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.27274901367429116), 'Dice': np.float64(0.4285982715270684), 'FPS': 13.735460193753475}
#
# image 1/1 /content/data/coco/images/val2017/000000184321.jpg: 480x640 1 train, 50.9ms
# Speed: 2.1ms preprocess, 50.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000184321.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.901558222783744), 'Dice': np.float64(0.9482309949615193), 'FPS': 14.595117786427702}
#
# image 1/1 /content/data/coco/images/val2017/000000565778.jpg: 416x640 2 persons, 1 train, 2 traffic lights, 49.1ms
# Speed: 1.9ms preprocess, 49.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
# Metric for: data/coco/images/val2017/000000565778.jpg
# {'mAP': np.float64(0.6), 'mIoU': np.float64(0.09428933122359844), 'Dice': np.float64(0.17232980078160354), 'FPS': 14.320593054811384}
#
# image 1/1 /content/data/coco/images/val2017/000000297343.jpg: 448x640 1 stop sign, 48.9ms
# Speed: 2.1ms preprocess, 48.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000297343.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.9519055203760538), 'Dice': np.float64(0.9753602420189476), 'FPS': 16.064947980406107}
#
# image 1/1 /content/data/coco/images/val2017/000000336587.jpg: 480x640 1 car, 1 traffic light, 1 stop sign, 54.0ms
# Speed: 1.9ms preprocess, 54.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000336587.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.26794238889182515), 'Dice': np.float64(0.4226412670468496), 'FPS': 14.626112948752125}
#
# image 1/1 /content/data/coco/images/val2017/000000122745.jpg: 640x480 1 stop sign, 53.4ms
# Speed: 1.9ms preprocess, 53.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000122745.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.93737721021611), 'Dice': np.float64(0.9676765115984282), 'FPS': 15.583507234115586}
#
# image 1/1 /content/data/coco/images/val2017/000000219578.jpg: 448x640 1 cat, 1 dog, 1 couch, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000219578.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.2077311479694017), 'Dice': np.float64(0.34400230269570664), 'FPS': 14.443633561454124}
#
# image 1/1 /content/data/coco/images/val2017/000000555705.jpg: 384x640 2 cats, 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000555705.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4680608827321274), 'Dice': np.float64(0.6376586805596851), 'FPS': 16.961883807852413}
#
# image 1/1 /content/data/coco/images/val2017/000000443303.jpg: 480x640 1 cat, 1 suitcase, 2 beds, 1 book, 50.9ms
# Speed: 3.4ms preprocess, 50.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000443303.jpg
# {'mAP': np.float64(0.6), 'mIoU': np.float64(0.18779081005456844), 'Dice': np.float64(0.3162018235280691), 'FPS': 14.043027609888886}
#
# image 1/1 /content/data/coco/images/val2017/000000500663.jpg: 480x640 4 cows, 50.4ms
# Speed: 2.7ms preprocess, 50.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000500663.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.1121119929453263), 'Dice': np.float64(0.20161996931335666), 'FPS': 14.95070647182215}
#
# image 1/1 /content/data/coco/images/val2017/000000418281.jpg: 448x640 2 cows, 1 bowl, 50.0ms
# Speed: 1.4ms preprocess, 50.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000418281.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.25301099662097576), 'Dice': np.float64(0.4038448142965648), 'FPS': 14.72061664821271}
#
# image 1/1 /content/data/coco/images/val2017/000000025560.jpg: 480x640 1 person, 1 cat, 1 cup, 1 tv, 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000025560.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.23113881665185723), 'Dice': np.float64(0.37548782237319206), 'FPS': 14.38335438416199}
#
# image 1/1 /content/data/coco/images/val2017/000000403817.jpg: 480x640 1 cat, 1 dog, 1 bowl, 1 laptop, 49.9ms
# Speed: 3.4ms preprocess, 49.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000403817.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.28414370562569075), 'Dice': np.float64(0.4425419123745867), 'FPS': 13.923916258431682}
#
# image 1/1 /content/data/coco/images/val2017/000000085329.jpg: 480x640 1 person, 1 tie, 52.9ms
# Speed: 2.3ms preprocess, 52.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000085329.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.36339143397450513), 'Dice': np.float64(0.5330698505493183), 'FPS': 14.822109012795892}
#
# image 1/1 /content/data/coco/images/val2017/000000329323.jpg: 640x448 18 persons, 1 handbag, 50.6ms
# Speed: 2.1ms preprocess, 50.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000329323.jpg
# {'mAP': np.float64(0.6842105263157895), 'mIoU': np.float64(0.04260371678889728), 'Dice': np.float64(0.08172561847393361), 'FPS': 12.054115054309248}
#
# image 1/1 /content/data/coco/images/val2017/000000239274.jpg: 640x608 14 persons, 2 boats, 63.1ms
# Speed: 2.4ms preprocess, 63.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 608)
# Metric for: data/coco/images/val2017/000000239274.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.03214856025625757), 'Dice': np.float64(0.06229444383137221), 'FPS': 9.767001607300086}
#
# image 1/1 /content/data/coco/images/val2017/000000286994.jpg: 480x640 1 bird, 9 elephants, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000286994.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.07088263460052803), 'Dice': np.float64(0.132381705165981), 'FPS': 14.491490865714084}
#
# image 1/1 /content/data/coco/images/val2017/000000511321.jpg: 640x448 5 boats, 47.8ms
# Speed: 2.4ms preprocess, 47.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000511321.jpg
# {'mAP': np.float64(0.6), 'mIoU': np.float64(0.1258826169066495), 'Dice': np.float64(0.22361588147174818), 'FPS': 14.910366841412158}
#
# image 1/1 /content/data/coco/images/val2017/000000314294.jpg: 384x640 1 elephant, 41.5ms
# Speed: 1.9ms preprocess, 41.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000314294.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4459091328839228), 'Dice': np.float64(0.6167872139994571), 'FPS': 17.629630176251464}
#
# image 1/1 /content/data/coco/images/val2017/000000233771.jpg: 640x640 8 persons, 2 cars, 4 buss, 3 umbrellas, 2 handbags, 1 clock, 68.4ms
# Speed: 1.8ms preprocess, 68.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Metric for: data/coco/images/val2017/000000233771.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.04144295291573029), 'Dice': np.float64(0.07958756223699504), 'FPS': 9.5825738073881}
#
# image 1/1 /content/data/coco/images/val2017/000000475779.jpg: 480x640 1 elephant, 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000475779.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.8377251787678768), 'Dice': np.float64(0.9116979931999831), 'FPS': 15.598053429859636}
#
# image 1/1 /content/data/coco/images/val2017/000000301867.jpg: 480x640 3 persons, 2 umbrellas, 6 handbags, 53.4ms
# Speed: 2.1ms preprocess, 53.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000301867.jpg
# {'mAP': np.float64(0.8181818181818182), 'mIoU': np.float64(0.09741577671706354), 'Dice': np.float64(0.1775366798689269), 'FPS': 12.868916160215123}
#
# image 1/1 /content/data/coco/images/val2017/000000312421.jpg: 448x640 9 persons, 1 motorcycle, 1 bench, 2 umbrellas, 1 suitcase, 1 laptop, 46.9ms
# Speed: 1.9ms preprocess, 46.9ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000312421.jpg
# {'mAP': np.float64(0.7333333333333333), 'mIoU': np.float64(0.05597053888356902), 'Dice': np.float64(0.10600776597942628), 'FPS': 13.242388468997392}
#
# image 1/1 /content/data/coco/images/val2017/000000185250.jpg: 640x416 2 persons, 1 dog, 2 frisbees, 63.1ms
# Speed: 1.4ms preprocess, 63.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 416)
# Metric for: data/coco/images/val2017/000000185250.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.12463338507522803), 'Dice': np.float64(0.22164269126136812), 'FPS': 11.429238049085319}
#
# image 1/1 /content/data/coco/images/val2017/000000356427.jpg: 448x640 1 person, 3 backpacks, 1 suitcase, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000356427.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.08124363392074756), 'Dice': np.float64(0.15027812672736163), 'FPS': 15.47415622577789}
#
# image 1/1 /content/data/coco/images/val2017/000000572517.jpg: 448x640 1 bird, 1 bear, 47.4ms
# Speed: 1.8ms preprocess, 47.4ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000572517.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4268943020451636), 'Dice': np.float64(0.5983544841875074), 'FPS': 15.460068028437044}
#
# image 1/1 /content/data/coco/images/val2017/000000270244.jpg: 448x640 1 zebra, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000270244.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.8715743383244068), 'Dice': np.float64(0.9313809454180854), 'FPS': 15.65680300802773}
#
# image 1/1 /content/data/coco/images/val2017/000000516316.jpg: 480x640 2 zebras, 51.2ms
# Speed: 2.2ms preprocess, 51.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000516316.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.07912080723445047), 'Dice': np.float64(0.14663938773865312), 'FPS': 14.408504324542426}
#
# image 1/1 /content/data/coco/images/val2017/000000125211.jpg: 480x640 1 zebra, 51.3ms
# Speed: 2.0ms preprocess, 51.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000125211.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.9379356123464985), 'Dice': np.float64(0.9679739681452304), 'FPS': 14.873988382258036}
#
# image 1/1 /content/data/coco/images/val2017/000000562121.jpg: 480x640 4 zebras, 52.5ms
# Speed: 1.9ms preprocess, 52.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000562121.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.13703120509687675), 'Dice': np.float64(0.24103332341736652), 'FPS': 14.089114681417614}
#
# image 1/1 /content/data/coco/images/val2017/000000360661.jpg: 480x640 5 persons, 3 horses, 49.8ms
# Speed: 2.5ms preprocess, 49.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000360661.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.10996013533977196), 'Dice': np.float64(0.19813348576903955), 'FPS': 14.173432116858029}
#
# image 1/1 /content/data/coco/images/val2017/000000016228.jpg: 448x640 15 persons, 2 benchs, 1 horse, 3 umbrellas, 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000016228.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.024104000331141212), 'Dice': np.float64(0.047073344744961935), 'FPS': 12.518173229238215}
#
# image 1/1 /content/data/coco/images/val2017/000000382088.jpg: 448x640 1 horse, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000382088.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.944057772113845), 'Dice': np.float64(0.971223988973678), 'FPS': 16.960169122781764}
#
# image 1/1 /content/data/coco/images/val2017/000000266409.jpg: 480x640 1 person, 1 traffic light, 1 backpack, 1 skis, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000266409.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.19060697829094736), 'Dice': np.float64(0.3201845474894721), 'FPS': 13.902593700431014}
#
# image 1/1 /content/data/coco/images/val2017/000000430961.jpg: 480x640 3 persons, 1 sports ball, 1 baseball glove, 52.2ms
# Speed: 3.5ms preprocess, 52.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000430961.jpg
# {'mAP': np.float64(0.6), 'mIoU': np.float64(0.13940582943027924), 'Dice': np.float64(0.24469916833756125), 'FPS': 14.685414189157527}
#
# image 1/1 /content/data/coco/images/val2017/000000080671.jpg: 448x640 1 person, 1 skis, 1 snowboard, 49.9ms
# Speed: 1.8ms preprocess, 49.9ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000080671.jpg
# {'mAP': np.float64(0.3333333333333333), 'mIoU': np.float64(0.2611589571610705), 'Dice': np.float64(0.41415708254406236), 'FPS': 15.25022919812773}
#
# image 1/1 /content/data/coco/images/val2017/000000577539.jpg: 448x640 1 person, 1 bowl, 47.7ms
# Speed: 3.0ms preprocess, 47.7ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000577539.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.13910339472859476), 'Dice': np.float64(0.2442331317285519), 'FPS': 15.447768994113376}
#
# image 1/1 /content/data/coco/images/val2017/000000104612.jpg: 480x640 1 bowl, 9 broccolis, 51.6ms
# Speed: 2.2ms preprocess, 51.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000104612.jpg
# {'mAP': np.float64(0.3), 'mIoU': np.float64(0.03091073445005096), 'Dice': np.float64(0.05996781955431007), 'FPS': 13.216267482650132}
#
# image 1/1 /content/data/coco/images/val2017/000000476258.jpg: 384x640 1 person, 1 skateboard, 40.0ms
# Speed: 2.2ms preprocess, 40.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000476258.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.3643752316057028), 'Dice': np.float64(0.5341275965217834), 'FPS': 17.993335580507}
#
# image 1/1 /content/data/coco/images/val2017/000000448365.jpg: 448x640 2 persons, 1 skateboard, 48.7ms
# Speed: 2.2ms preprocess, 48.7ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000448365.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.17574619441035746), 'Dice': np.float64(0.29895260600608625), 'FPS': 14.851026341103577}
#
# image 1/1 /content/data/coco/images/val2017/000000035197.jpg: 640x448 2 persons, 1 skateboard, 50.6ms
# Speed: 2.5ms preprocess, 50.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000035197.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.21347573571861467), 'Dice': np.float64(0.3518417870831102), 'FPS': 14.883330405055032}
#
# image 1/1 /content/data/coco/images/val2017/000000349860.jpg: 448x640 3 persons, 2 cars, 1 bench, 1 skateboard, 49.0ms
# Speed: 2.1ms preprocess, 49.0ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000349860.jpg
# {'mAP': np.float64(0.2857142857142857), 'mIoU': np.float64(0.06169671432133585), 'Dice': np.float64(0.11622286004864203), 'FPS': 14.623155357821192}
#
# image 1/1 /content/data/coco/images/val2017/000000180135.jpg: 640x448 1 person, 1 skateboard, 47.8ms
# Speed: 3.0ms preprocess, 47.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000180135.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4059183106238418), 'Dice': np.float64(0.5774422419233242), 'FPS': 16.21073546081433}
#
# image 1/1 /content/data/coco/images/val2017/000000486438.jpg: 448x640 1 person, 8 donuts, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000486438.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.09755485640120584), 'Dice': np.float64(0.17776761832402688), 'FPS': 13.57137520191394}
#
# image 1/1 /content/data/coco/images/val2017/000000400573.jpg: 640x480 2 persons, 1 donut, 48.8ms
# Speed: 1.5ms preprocess, 48.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000400573.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.1662779389712729), 'Dice': np.float64(0.2851429036168514), 'FPS': 15.66177239728525}
#
# image 1/1 /content/data/coco/images/val2017/000000109798.jpg: 448x640 1 cup, 3 donuts, 51.0ms
# Speed: 2.3ms preprocess, 51.0ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000109798.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.17289072500865355), 'Dice': np.float64(0.29481130905417974), 'FPS': 14.970290322879304}
#
# image 1/1 /content/data/coco/images/val2017/000000370677.jpg: 448x640 3 persons, 6 donuts, 46.2ms
# Speed: 3.1ms preprocess, 46.2ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000370677.jpg
# {'mAP': np.float64(0.5555555555555556), 'mIoU': np.float64(0.02916802644114986), 'Dice': np.float64(0.05668272952865147), 'FPS': 14.618925023210817}
#
# image 1/1 /content/data/coco/images/val2017/000000238866.jpg: 448x640 20 donuts, 46.5ms
# Speed: 2.0ms preprocess, 46.5ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000238866.jpg
# {'mAP': np.float64(0.45), 'mIoU': np.float64(0.03458985893439639), 'Dice': np.float64(0.06686680453261573), 'FPS': 12.545168819461612}
#
# image 1/1 /content/data/coco/images/val2017/000000369370.jpg: 480x640 4 sandwichs, 1 broccoli, 1 dining table, 47.6ms
# Speed: 2.1ms preprocess, 47.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000369370.jpg
# {'mAP': np.float64(0.8333333333333334), 'mIoU': np.float64(0.09962988707250424), 'Dice': np.float64(0.18120621900836917), 'FPS': 14.984409646170633}
#
# image 1/1 /content/data/coco/images/val2017/000000502737.jpg: 640x480 1 person, 1 cup, 1 donut, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000502737.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.23221270261716745), 'Dice': np.float64(0.37690360134083595), 'FPS': 14.642043298071671}
#
# image 1/1 /content/data/coco/images/val2017/000000515579.jpg: 448x640 4 persons, 1 boat, 1 sports ball, 50.2ms
# Speed: 3.0ms preprocess, 50.2ms inference, 3.8ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000515579.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.07321440941920089), 'Dice': np.float64(0.1364394826916699), 'FPS': 14.36365171188809}
#
# image 1/1 /content/data/coco/images/val2017/000000515445.jpg: 480x640 8 persons, 2 surfboards, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000515445.jpg
# {'mAP': np.float64(0.7), 'mIoU': np.float64(0.06780242033592539), 'Dice': np.float64(0.12699431850809081), 'FPS': 14.102758010079377}
#
# image 1/1 /content/data/coco/images/val2017/000000173383.jpg: 448x640 2 cups, 1 knife, 1 cake, 1 dining table, 48.2ms
# Speed: 1.9ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000173383.jpg
# {'mAP': np.float64(0.6), 'mIoU': np.float64(0.12398582627218183), 'Dice': np.float64(0.22061813125062968), 'FPS': 14.821585237809298}
#
# image 1/1 /content/data/coco/images/val2017/000000438862.jpg: 448x640 5 persons, 1 bench, 1 sports ball, 46.7ms
# Speed: 1.6ms preprocess, 46.7ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000438862.jpg
# {'mAP': np.float64(0.8571428571428571), 'mIoU': np.float64(0.0696471733841642), 'Dice': np.float64(0.1302245733306872), 'FPS': 14.364291200057407}
#
# image 1/1 /content/data/coco/images/val2017/000000180560.jpg: 448x640 3 persons, 2 cakes, 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000180560.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.1972324278570633), 'Dice': np.float64(0.32948059753124354), 'FPS': 15.432195568851837}
#
# image 1/1 /content/data/coco/images/val2017/000000347693.jpg: 448x640 2 beds, 49.8ms
# Speed: 1.4ms preprocess, 49.8ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000347693.jpg
# {'mAP': np.float64(0.0), 'mIoU': np.float64(0.04566810138970215), 'Dice': np.float64(0.08734722103315351), 'FPS': 15.372298910385389}
#
# image 1/1 /content/data/coco/images/val2017/000000039956.jpg: 448x640 2 chairs, 1 bed, 1 book, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000039956.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.18743305030222795), 'Dice': np.float64(0.31569451474257365), 'FPS': 15.017942474573395}
#
# image 1/1 /content/data/coco/images/val2017/000000321214.jpg: 480x640 1 person, 1 cake, 51.3ms
# Speed: 2.2ms preprocess, 51.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000321214.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.29884090633349364), 'Dice': np.float64(0.46016552893624757), 'FPS': 14.987193865226}
#
# image 1/1 /content/data/coco/images/val2017/000000474028.jpg: 448x640 12 persons, 1 sports ball, 48.1ms
# Speed: 1.4ms preprocess, 48.1ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000474028.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.0522869486615827), 'Dice': np.float64(0.099377738606541), 'FPS': 12.938905503787936}
#
# image 1/1 /content/data/coco/images/val2017/000000066523.jpg: 640x480 1 bed, 49.0ms
# Speed: 2.2ms preprocess, 49.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000066523.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.8250564412490015), 'Dice': np.float64(0.9041434802798354), 'FPS': 15.734509308061025}
#
# image 1/1 /content/data/coco/images/val2017/000000355257.jpg: 448x640 3 persons, 1 bed, 2 tvs, 1 clock, 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000355257.jpg
# {'mAP': np.float64(0.2857142857142857), 'mIoU': np.float64(0.10954623397709116), 'Dice': np.float64(0.19746132359790058), 'FPS': 13.557907453547463}
#
# image 1/1 /content/data/coco/images/val2017/000000142092.jpg: 480x640 1 bottle, 1 pizza, 1 oven, 50.6ms
# Speed: 2.2ms preprocess, 50.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000142092.jpg
# {'mAP': np.float64(0.3333333333333333), 'mIoU': np.float64(0.32801355355800665), 'Dice': np.float64(0.49399127392818326), 'FPS': 14.555055286827606}
#
# image 1/1 /content/data/coco/images/val2017/000000063154.jpg: 448x640 1 person, 1 surfboard, 49.1ms
# Speed: 2.1ms preprocess, 49.1ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000063154.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.41760976300050395), 'Dice': np.float64(0.5891745018976079), 'FPS': 15.217970876357915}
#
# image 1/1 /content/data/coco/images/val2017/000000199551.jpg: 448x640 1 person, 1 bed, 50.1ms
# Speed: 1.8ms preprocess, 50.1ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000199551.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.36459518633270077), 'Dice': np.float64(0.5343638757990007), 'FPS': 15.256552992494953}
#
# image 1/1 /content/data/coco/images/val2017/000000239347.jpg: 480x640 3 persons, 1 bed, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000239347.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.19151379387224016), 'Dice': np.float64(0.32146299078896806), 'FPS': 13.932657986217235}
#
# image 1/1 /content/data/coco/images/val2017/000000514508.jpg: 480x640 4 persons, 49.7ms
# Speed: 2.3ms preprocess, 49.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000514508.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.18744555032448612), 'Dice': np.float64(0.3157122451185471), 'FPS': 14.845401991558518}
#
# image 1/1 /content/data/coco/images/val2017/000000473237.jpg: 448x640 1 person, 1 pizza, 1 chair, 50.9ms
# Speed: 1.7ms preprocess, 50.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000473237.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.28534754622655356), 'Dice': np.float64(0.44400060834014865), 'FPS': 14.871720621650013}
#
# image 1/1 /content/data/coco/images/val2017/000000228144.jpg: 448x640 1 chair, 1 couch, 1 potted plant, 48.2ms
# Speed: 1.9ms preprocess, 48.2ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000228144.jpg
# {'mAP': np.float64(0.3333333333333333), 'mIoU': np.float64(0.07614472274028909), 'Dice': np.float64(0.1415139081784364), 'FPS': 15.380528971190893}
#
# image 1/1 /content/data/coco/images/val2017/000000206027.jpg: 480x640 4 bottles, 1 pizza, 1 dining table, 51.2ms
# Speed: 1.7ms preprocess, 51.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000206027.jpg
# {'mAP': np.float64(0.8333333333333334), 'mIoU': np.float64(0.1491362680185909), 'Dice': np.float64(0.2595623724864946), 'FPS': 14.025840184868123}
#
# image 1/1 /content/data/coco/images/val2017/000000078915.jpg: 640x512 12 persons, 2 backpacks, 1 sports ball, 1 tennis racket, 9 chairs, 50.9ms
# Speed: 1.8ms preprocess, 50.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 512)
# Metric for: data/coco/images/val2017/000000078915.jpg
# {'mAP': np.float64(0.32), 'mIoU': np.float64(0.028324929901521242), 'Dice': np.float64(0.05508945485593511), 'FPS': 10.591751811201236}
#
# image 1/1 /content/data/coco/images/val2017/000000551215.jpg: 640x480 1 person, 1 tennis racket, 46.9ms
# Speed: 2.5ms preprocess, 46.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000551215.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.420506189831522), 'Dice': np.float64(0.5920511896979425), 'FPS': 15.307276915315544}
#
# image 1/1 /content/data/coco/images/val2017/000000544519.jpg: 448x640 1 person, 1 toothbrush, 51.4ms
# Speed: 2.0ms preprocess, 51.4ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000544519.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.3822659489935015), 'Dice': np.float64(0.5531004352264467), 'FPS': 14.148236323143184}
#
# image 1/1 /content/data/coco/images/val2017/000000096493.jpg: 640x448 2 persons, 1 couch, 1 bed, 1 cell phone, 48.9ms
# Speed: 2.1ms preprocess, 48.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000096493.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.2632323100329396), 'Dice': np.float64(0.41675993867838235), 'FPS': 14.749242666921564}
#
# image 1/1 /content/data/coco/images/val2017/000000023899.jpg: 448x640 3 persons, 1 couch, 4 remotes, 49.3ms
# Speed: 2.0ms preprocess, 49.3ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000023899.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.0674225233572723), 'Dice': np.float64(0.1263277135003935), 'FPS': 14.297015778874544}
#
# image 1/1 /content/data/coco/images/val2017/000000340175.jpg: 416x640 1 bench, 6 chairs, 1 couch, 1 potted plant, 2 dining tables, 3 vases, 44.0ms
# Speed: 1.9ms preprocess, 44.0ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
# Metric for: data/coco/images/val2017/000000340175.jpg
# {'mAP': np.float64(0.7857142857142857), 'mIoU': np.float64(0.023005882147404885), 'Dice': np.float64(0.04497702808729299), 'FPS': 13.688883689385655}
#
# image 1/1 /content/data/coco/images/val2017/000000578500.jpg: 320x640 5 chairs, 3 couchs, 2 potted plants, 1 dining table, 3 vases, 85.9ms
# Speed: 1.6ms preprocess, 85.9ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
# Metric for: data/coco/images/val2017/000000578500.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.04892265546938535), 'Dice': np.float64(0.09328172142014192), 'FPS': 9.08855006264097}
#
# image 1/1 /content/data/coco/images/val2017/000000366141.jpg: 480x640 1 cat, 1 chair, 1 couch, 1 tv, 1 remote, 47.4ms
# Speed: 1.7ms preprocess, 47.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000366141.jpg
# {'mAP': np.float64(0.6), 'mIoU': np.float64(0.17584631591512526), 'Dice': np.float64(0.2990974475746338), 'FPS': 15.129919162092738}
#
# image 1/1 /content/data/coco/images/val2017/000000057597.jpg: 448x640 19 persons, 3 cars, 2 trucks, 1 sports ball, 46.1ms
# Speed: 2.3ms preprocess, 46.1ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000057597.jpg
# {'mAP': np.float64(0.52), 'mIoU': np.float64(0.014125181968383058), 'Dice': np.float64(0.027856880431598303), 'FPS': 11.64967318940856}
#
# image 1/1 /content/data/coco/images/val2017/000000559842.jpg: 448x640 16 persons, 1 backpack, 1 sports ball, 1 cup, 1 chair, 44.0ms
# Speed: 2.1ms preprocess, 44.0ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000559842.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.03616347392411097), 'Dice': np.float64(0.06980264183054882), 'FPS': 12.259415653003694}
#
# image 1/1 /content/data/coco/images/val2017/000000434230.jpg: 416x640 1 person, 12 vases, 44.1ms
# Speed: 3.4ms preprocess, 44.1ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
# Metric for: data/coco/images/val2017/000000434230.jpg
# {'mAP': np.float64(0.38461538461538464), 'mIoU': np.float64(0.014761830885270966), 'Dice': np.float64(0.029094178428829647), 'FPS': 14.169793031667027}
#
# image 1/1 /content/data/coco/images/val2017/000000428454.jpg: 448x640 1 person, 1 snowboard, 1 kite, 46.8ms
# Speed: 2.2ms preprocess, 46.8ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000428454.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.12660857010866167), 'Dice': np.float64(0.22476053079633548), 'FPS': 16.26170724158277}
#
# image 1/1 /content/data/coco/images/val2017/000000399462.jpg: 640x448 3 persons, 1 kite, 50.9ms
# Speed: 2.5ms preprocess, 50.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000399462.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.19919523087504182), 'Dice': np.float64(0.3322148483357308), 'FPS': 14.90358528855862}
#
# image 1/1 /content/data/coco/images/val2017/000000261061.jpg: 448x640 1 person, 1 frisbee, 48.5ms
# Speed: 3.4ms preprocess, 48.5ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000261061.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.09003957096740603), 'Dice': np.float64(0.1652042244438819), 'FPS': 15.611406476524184}
#
# image 1/1 /content/data/coco/images/val2017/000000168330.jpg: 416x640 5 cars, 1 traffic light, 1 fire hydrant, 2 clocks, 48.5ms
# Speed: 1.9ms preprocess, 48.5ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
# Metric for: data/coco/images/val2017/000000168330.jpg
# {'mAP': np.float64(0.8888888888888888), 'mIoU': np.float64(0.0853085990970527), 'Dice': np.float64(0.15720616084315028), 'FPS': 13.735550155807921}
#
# image 1/1 /content/data/coco/images/val2017/000000383384.jpg: 384x640 5 persons, 2 baseball bats, 1 baseball glove, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000383384.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.0434088596183407), 'Dice': np.float64(0.08320584825054839), 'FPS': 16.265869484782364}
#
# image 1/1 /content/data/coco/images/val2017/000000342006.jpg: 640x480 2 boats, 2 clocks, 50.2ms
# Speed: 2.3ms preprocess, 50.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000342006.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.14147518511327056), 'Dice': np.float64(0.24788131526351445), 'FPS': 14.845296904087403}
#
# image 1/1 /content/data/coco/images/val2017/000000217285.jpg: 448x640 15 persons, 1 baseball bat, 1 baseball glove, 9 chairs, 46.0ms
# Speed: 2.2ms preprocess, 46.0ms inference, 2.7ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000217285.jpg
# {'mAP': np.float64(0.5769230769230769), 'mIoU': np.float64(0.019106903269870926), 'Dice': np.float64(0.037497348332280314), 'FPS': 11.225185584680732}
#
# image 1/1 /content/data/coco/images/val2017/000000236412.jpg: 480x640 1 pizza, 1 dining table, 47.2ms
# Speed: 2.5ms preprocess, 47.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000236412.jpg
# {'mAP': np.float64(0.5), 'mIoU': np.float64(0.22238495321302418), 'Dice': np.float64(0.36385420587596073), 'FPS': 15.29761845361275}
#
# image 1/1 /content/data/coco/images/val2017/000000524456.jpg: 480x640 1 person, 1 laptop, 1 mouse, 51.7ms
# Speed: 2.4ms preprocess, 51.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000524456.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.1636843468278892), 'Dice': np.float64(0.28132087068813755), 'FPS': 14.348271975237367}
#
# image 1/1 /content/data/coco/images/val2017/000000153343.jpg: 480x640 2 teddy bears, 51.7ms
# Speed: 2.1ms preprocess, 51.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000153343.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4478419718415442), 'Dice': np.float64(0.6186337743364678), 'FPS': 14.632797429462798}
#
# image 1/1 /content/data/coco/images/val2017/000000095786.jpg: 448x640 3 cups, 1 dining table, 50.0ms
# Speed: 2.9ms preprocess, 50.0ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000095786.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.23123579027872693), 'Dice': np.float64(0.3756157709261843), 'FPS': 15.126754331629115}
#
# image 1/1 /content/data/coco/images/val2017/000000326541.jpg: 384x640 5 persons, 2 cell phones, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000326541.jpg
# ...
# Speed: 2.2ms preprocess, 50.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000001000.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.048838304048428635), 'Dice': np.float64(0.09312837614705116), 'FPS': 12.433454627764368}
#
# image 1/1 /content/data/coco/images/val2017/000000379842.jpg: 384x640 1 remote, 2 books, 39.0ms
# Speed: 1.8ms preprocess, 39.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000379842.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.2010155987908184), 'Dice': np.float64(0.3347426944216224), 'FPS': 17.816321274907764}
#
# image 1/1 /content/data/coco/images/val2017/000000013923.jpg: 448x640 6 chairs, 1 couch, 3 potted plants, 1 dining table, 1 tv, 1 book, 2 vases, 47.3ms
# Speed: 1.9ms preprocess, 47.3ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000013923.jpg
# {'mAP': np.float64(0.7333333333333333), 'mIoU': np.float64(0.035891313439904045), 'Dice': np.float64(0.06929551966358145), 'FPS': 12.630204754507718}
#
# image 1/1 /content/data/coco/images/val2017/000000559543.jpg: 448x640 1 person, 1 chair, 2 couchs, 2 potted plants, 1 remote, 1 vase, 44.3ms
# Speed: 3.3ms preprocess, 44.3ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000559543.jpg
# {'mAP': np.float64(0.625), 'mIoU': np.float64(0.12158926000152044), 'Dice': np.float64(0.21681602051245677), 'FPS': 15.335035959581782}
#
# image 1/1 /content/data/coco/images/val2017/000000185890.jpg: 640x512 5 persons, 5 remotes, 49.4ms
# Speed: 2.3ms preprocess, 49.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 512)
# Metric for: data/coco/images/val2017/000000185890.jpg
# {'mAP': np.float64(0.9), 'mIoU': np.float64(0.045977252613156695), 'Dice': np.float64(0.08791252868700937), 'FPS': 13.113625910118499}
#
# image 1/1 /content/data/coco/images/val2017/000000357978.jpg: 480x640 4 persons, 1 chair, 1 couch, 1 remote, 48.5ms
# Speed: 3.1ms preprocess, 48.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000357978.jpg
# {'mAP': np.float64(0.7142857142857143), 'mIoU': np.float64(0.05630491567239257), 'Dice': np.float64(0.10660731543893572), 'FPS': 14.47024287277495}
#
# image 1/1 /content/data/coco/images/val2017/000000129492.jpg: 480x640 3 persons, 1 chair, 1 couch, 1 remote, 1 cell phone, 1 book, 49.5ms
# Speed: 2.2ms preprocess, 49.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000129492.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.07904889995148985), 'Dice': np.float64(0.14651588070761873), 'FPS': 14.290391043831821}
#
# image 1/1 /content/data/coco/images/val2017/000000261097.jpg: 640x448 8 persons, 1 tennis racket, 45.5ms
# Speed: 3.0ms preprocess, 45.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000261097.jpg
# {'mAP': np.float64(0.7777777777777778), 'mIoU': np.float64(0.02206362470139365), 'Dice': np.float64(0.04317465990992442), 'FPS': 14.886235683744722}
#
# image 1/1 /content/data/coco/images/val2017/000000410510.jpg: 448x640 1 person, 1 sports ball, 1 tennis racket, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000410510.jpg
# {'mAP': np.float64(0.3333333333333333), 'mIoU': np.float64(0.2089266526921786), 'Dice': np.float64(0.34563991492273977), 'FPS': 15.111331113301338}
#
# image 1/1 /content/data/coco/images/val2017/000000039951.jpg: 448x640 1 person, 1 sports ball, 1 tennis racket, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 3.3ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000039951.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.15921773026692826), 'Dice': np.float64(0.274698576651801), 'FPS': 15.118194101928434}
#
# image 1/1 /content/data/coco/images/val2017/000000306700.jpg: 640x480 1 person, 1 fork, 1 pizza, 2 dining tables, 52.3ms
# Speed: 1.9ms preprocess, 52.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000306700.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.20804724415014317), 'Dice': np.float64(0.34443560905021336), 'FPS': 13.725526641039032}
#
# image 1/1 /content/data/coco/images/val2017/000000146457.jpg: 480x640 2 persons, 2 bottles, 1 bowl, 2 pizzas, 1 chair, 1 dining table, 1 refrigerator, 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000146457.jpg
# {'mAP': np.float64(0.9), 'mIoU': np.float64(0.056924987454858585), 'Dice': np.float64(0.10771812215725454), 'FPS': 13.945118862153473}
#
# image 1/1 /content/data/coco/images/val2017/000000214224.jpg: 448x640 4 bottles, 46.8ms
# Speed: 1.7ms preprocess, 46.8ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000214224.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.10359818560971962), 'Dice': np.float64(0.1877462050238572), 'FPS': 15.44202476861753}
#
# image 1/1 /content/data/coco/images/val2017/000000332845.jpg: 480x640 1 person, 1 chair, 1 bed, 1 laptop, 52.4ms
# Speed: 2.2ms preprocess, 52.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000332845.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.21596129722652685), 'Dice': np.float64(0.3552108076451293), 'FPS': 14.228243563642096}
#
# image 1/1 /content/data/coco/images/val2017/000000255483.jpg: 640x608 3 persons, 1 bottle, 3 books, 68.7ms
# Speed: 3.4ms preprocess, 68.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 608)
# Metric for: data/coco/images/val2017/000000255483.jpg
# {'mAP': np.float64(0.42857142857142855), 'mIoU': np.float64(0.11252444298711739), 'Dice': np.float64(0.2022866889737548), 'FPS': 10.915867153004637}
#
# image 1/1 /content/data/coco/images/val2017/000000222455.jpg: 640x640 1 oven, 1 refrigerator, 68.1ms
# Speed: 4.4ms preprocess, 68.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Metric for: data/coco/images/val2017/000000222455.jpg
# {'mAP': np.float64(0.0), 'mIoU': np.float64(0.41952940204985584), 'Dice': np.float64(0.5910823705997762), 'FPS': 11.439462425588005}
#
# image 1/1 /content/data/coco/images/val2017/000000187271.jpg: 640x480 1 refrigerator, 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000187271.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.9715725146411552), 'Dice': np.float64(0.9855813138255183), 'FPS': 14.66195384690901}
#
# image 1/1 /content/data/coco/images/val2017/000000462629.jpg: 448x640 1 chair, 9 refrigerators, 49.6ms
# Speed: 2.1ms preprocess, 49.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000462629.jpg
# {'mAP': np.float64(0.8), 'mIoU': np.float64(0.08090373581807145), 'Dice': np.float64(0.14969646812598023), 'FPS': 13.457637109887408}
#
# image 1/1 /content/data/coco/images/val2017/000000544565.jpg: 640x640 1 fork, 2 knifes, 1 spoon, 1 bowl, 1 sandwich, 1 orange, 67.7ms
# Speed: 2.9ms preprocess, 67.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Metric for: data/coco/images/val2017/000000544565.jpg
# {'mAP': np.float64(0.42857142857142855), 'mIoU': np.float64(0.06818576500105182), 'Dice': np.float64(0.1276664925430544), 'FPS': 10.718698917509592}
#
# image 1/1 /content/data/coco/images/val2017/000000369771.jpg: 480x640 1 spoon, 3 bowls, 1 sandwich, 1 broccoli, 1 dining table, 48.2ms
# Speed: 2.1ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000369771.jpg
# {'mAP': np.float64(0.8571428571428571), 'mIoU': np.float64(0.07220164022977146), 'Dice': np.float64(0.13467921987938528), 'FPS': 14.256390033909657}
#
# image 1/1 /content/data/coco/images/val2017/000000035963.jpg: 640x480 3 teddy bears, 49.4ms
# Speed: 2.2ms preprocess, 49.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000035963.jpg
# {'mAP': np.float64(0.6666666666666666), 'mIoU': np.float64(0.2901259152811319), 'Dice': np.float64(0.4497637197186453), 'FPS': 14.311455573276747}
#
# image 1/1 /content/data/coco/images/val2017/000000289516.jpg: 640x320 2 clocks, 53.7ms
# Speed: 1.5ms preprocess, 53.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 320)
# Metric for: data/coco/images/val2017/000000289516.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.35769105903530746), 'Dice': np.float64(0.5269108265166906), 'FPS': 13.795863904430739}
#
# image 1/1 /content/data/coco/images/val2017/000000334309.jpg: 448x640 2 persons, 4 cars, 1 hot dog, 1 chair, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000334309.jpg
# {'mAP': np.float64(0.625), 'mIoU': np.float64(0.07029048671506097), 'Dice': np.float64(0.13134842846412054), 'FPS': 13.729030959766316}
#
# image 1/1 /content/data/coco/images/val2017/000000452084.jpg: 640x640 1 fork, 1 spoon, 2 bowls, 1 hot dog, 1 cake, 1 dining table, 66.8ms
# Speed: 2.7ms preprocess, 66.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Metric for: data/coco/images/val2017/000000452084.jpg
# {'mAP': np.float64(0.7142857142857143), 'mIoU': np.float64(0.14242178712382275), 'Dice': np.float64(0.2493331074898105), 'FPS': 10.435819534225036}
#
# image 1/1 /content/data/coco/images/val2017/000000301718.jpg: 640x480 2 persons, 3 bottles, 1 cup, 2 knifes, 1 bowl, 1 broccoli, 1 dining table, 48.8ms
# Speed: 2.2ms preprocess, 48.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000301718.jpg
# {'mAP': np.float64(0.7272727272727273), 'mIoU': np.float64(0.0661303614445288), 'Dice': np.float64(0.12405680174969784), 'FPS': 13.381043289093876}
#
# image 1/1 /content/data/coco/images/val2017/000000429598.jpg: 480x640 1 bottle, 1 oven, 1 sink, 1 refrigerator, 47.4ms
# Speed: 2.2ms preprocess, 47.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000429598.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.22090425356877919), 'Dice': np.float64(0.3618699057244862), 'FPS': 14.950066992957444}
#
# image 1/1 /content/data/coco/images/val2017/000000165257.jpg: 384x640 1 sink, 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000165257.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.6018181818181818), 'Dice': np.float64(0.7514188422247446), 'FPS': 16.988402617684727}
#
# image 1/1 /content/data/coco/images/val2017/000000093437.jpg: 384x640 1 person, 1 bottle, 1 cup, 1 bowl, 7 chairs, 3 potted plants, 1 vase, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Metric for: data/coco/images/val2017/000000093437.jpg
# {'mAP': np.float64(0.5333333333333333), 'mIoU': np.float64(0.03381795489332834), 'Dice': np.float64(0.06542342340497995), 'FPS': 14.759051787593298}
#
# image 1/1 /content/data/coco/images/val2017/000000413552.jpg: 640x448 2 persons, 1 toothbrush, 45.1ms
# Speed: 2.1ms preprocess, 45.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000413552.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.2453085975808716), 'Dice': np.float64(0.39397238252013433), 'FPS': 15.972082834709624}
#
# image 1/1 /content/data/coco/images/val2017/000000062025.jpg: 640x480 2 cups, 1 toilet, 1 sink, 53.8ms
# Speed: 2.1ms preprocess, 53.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000062025.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.14222911152001422), 'Dice': np.float64(0.2490377982587814), 'FPS': 13.91901829014479}
#
# image 1/1 /content/data/coco/images/val2017/000000017379.jpg: 640x480 2 persons, 1 tv, 2 sinks, 49.8ms
# Speed: 2.1ms preprocess, 49.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Metric for: data/coco/images/val2017/000000017379.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.19518692088750256), 'Dice': np.float64(0.3266215810704552), 'FPS': 13.683122885823916}
#
# image 1/1 /content/data/coco/images/val2017/000000176778.jpg: 640x448 1 cat, 1 toilet, 47.3ms
# Speed: 2.0ms preprocess, 47.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000176778.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.4240799762465413), 'Dice': np.float64(0.5955844942982658), 'FPS': 15.455624451999787}
#
# image 1/1 /content/data/coco/images/val2017/000000104572.jpg: 448x640 1 toilet, 5 sinks, 49.5ms
# Speed: 2.4ms preprocess, 49.5ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000104572.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.11740361873851518), 'Dice': np.float64(0.2101364569967245), 'FPS': 12.715090670835067}
#
# image 1/1 /content/data/coco/images/val2017/000000090108.jpg: 480x640 1 bottle, 1 toilet, 2 sinks, 50.1ms
# Speed: 1.9ms preprocess, 50.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000090108.jpg
# {'mAP': np.float64(0.75), 'mIoU': np.float64(0.24211940219703734), 'Dice': np.float64(0.38984883702610407), 'FPS': 14.44358382308703}
#
# image 1/1 /content/data/coco/images/val2017/000000157124.jpg: 448x640 1 sink, 48.5ms
# Speed: 2.0ms preprocess, 48.5ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000157124.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.9083997103548154), 'Dice': np.float64(0.9520015177385696), 'FPS': 14.604417788335432}
#
# image 1/1 /content/data/coco/images/val2017/000000089556.jpg: 480x640 1 person, 13 cars, 2 traffic lights, 1 fire hydrant, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Metric for: data/coco/images/val2017/000000089556.jpg
# {'mAP': np.float64(0.6470588235294118), 'mIoU': np.float64(0.04166639193600488), 'Dice': np.float64(0.07999949361631063), 'FPS': 12.45816117019123}
#
# image 1/1 /content/data/coco/images/val2017/000000266206.jpg: 640x448 (no detections), 46.0ms
# Speed: 1.8ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
# Metric for: data/coco/images/val2017/000000266206.jpg
# {'mAP': 0, 'mIoU': 0, 'Dice': 0, 'FPS': 17.94575803230104}
#
# image 1/1 /content/data/coco/images/val2017/000000086220.jpg: 448x640 2 persons, 2 cars, 1 bus, 1 train, 53.5ms
# Speed: 2.4ms preprocess, 53.5ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Metric for: data/coco/images/val2017/000000086220.jpg
# {'mAP': np.float64(0.8333333333333334), 'mIoU': np.float64(0.1671860867220904), 'Dice': np.float64(0.2864771755318186), 'FPS': 13.534282999898922}
#
# image 1/1 /content/data/coco/images/val2017/000000508602.jpg: 576x640 2 cars, 1 bird, 62.4ms
# Speed: 3.7ms preprocess, 62.4ms inference, 2.3ms postprocess per image at shape (1, 3, 576, 640)
# Metric for: data/coco/images/val2017/000000508602.jpg
# {'mAP': np.float64(1.0), 'mIoU': np.float64(0.28291854581874115), 'Dice': np.float64(0.44105457316962615), 'FPS': 12.147924197103524}
# Mask R-CNN Results: {'mAP': np.float64(0.6537778986448113), 'mIoU': np.float64(0.19467397941606904), 'Dice': np.float64(0.2857543983932439), 'FPS': np.float64(6.502511135986127)}
# YOLOv8 Results: {'mAP': np.float64(0.7468849721254806), 'mIoU': np.float64(0.22134537793922862), 'Dice': np.float64(0.31388746962096237), 'FPS': np.float64(13.991078802013574)}

# %%
import pandas as pd

results_df = pd.DataFrame({
    'Model': ['Mask R-CNN', 'YOLOv8'],
    'mAP@0.5': [maskrcnn_results['mAP'], yolov8_results['mAP']],
    'mIoU': [maskrcnn_results['mIoU'], yolov8_results['mIoU']],
    'Dice': [maskrcnn_results['Dice'], yolov8_results['Dice']],
    'FPS': [maskrcnn_results['FPS'], yolov8_results['FPS']]
})

print(results_df)
# Out:
#         Model   mAP@0.5      mIoU      Dice        FPS
# 0  Mask R-CNN  0.653778  0.194674  0.285754   6.502511
# 1      YOLOv8  0.746885  0.221345  0.313887  13.991079

# %%
COCO_CLASS_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana',
    'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut',
    'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A', 'N/A',
    'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book', 'clock',
    'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# %%
def visualize_results(img_id, coco):
    img_info = coco.loadImgs(img_id)[0]
    img_path = f"data/coco/images/val2017/{img_info['file_name']}"
    image = np.array(Image.open(img_path))
    img_height, img_width = image.shape[:2]

    # Create figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24, 8))

    # Ground truth visualization
    ax1.imshow(image)
    for ann in coco.loadAnns(coco.getAnnIds(imgIds=img_id)):
        # Draw bounding box
        bbox = ann['bbox']
        x, y, w, h = bbox
        rect = plt.Rectangle((x, y), w, h, fill=False,
                           color='red', linewidth=2, linestyle='-')
        ax1.add_patch(rect)

        # Draw segmentation mask
        mask = coco.annToMask(ann)
        color = np.random.random(3)
        image_masked = image.copy()
        image_masked[mask == 1] = image_masked[mask == 1] * 0.7 + color * 255 * 0.3
        ax1.imshow(image_masked)

        # Add label
        class_name = COCO_CLASS_NAMES[ann['category_id']]
        ax1.text(x, y - 5, class_name,
                bbox=dict(facecolor='red', alpha=0.5),
                fontsize=8, color='white')
    ax1.set_title('Ground Truth')

    # Mask R-CNN visualization
    ax2.imshow(image)
    image_tensor = F.to_tensor(Image.open(img_path)).unsqueeze(0).to(device)
    with torch.no_grad():
        outputs = maskrcnn_model(image_tensor)[0]

    for i in range(len(outputs['boxes'])):
        if outputs['scores'][i] < CONFIDENCE_THRESHOLD:  # Confidence threshold
            continue

        # Draw bounding box
        box = outputs['boxes'][i].cpu().numpy()
        x1, y1, x2, y2 = box
        width = x2 - x1
        height = y2 - y1
        rect = plt.Rectangle((x1, y1), width, height,
                           fill=False, color='blue', linewidth=2)
        ax2.add_patch(rect)

        # Draw segmentation mask
        mask = outputs['masks'][i].squeeze().cpu().numpy() > CONFIDENCE_THRESHOLD
        color = np.random.random(3)
        image_masked = image.copy()
        image_masked[mask] = image_masked[mask] * 0.7 + color * 255 * 0.3
        ax2.imshow(image_masked)

        # Add label and confidence
        class_name = COCO_CLASS_NAMES[outputs['labels'][i].item()]
        score = outputs['scores'][i].item()
        ax2.text(x1, y1 - 5, f"{class_name}: {score:.2f}",
                bbox=dict(facecolor='blue', alpha=0.5),
                fontsize=8, color='white')
    ax2.set_title('Mask R-CNN')

    # YOLOv8 visualization
    ax3.imshow(image)
    results = yolov8_model(img_path)
    result = results[0]

    if result.masks is not None:
        for i in range(len(result.boxes)):
            if result.boxes.conf[i] < CONFIDENCE_THRESHOLD:  # Confidence threshold
                continue

            # Draw bounding box
            box = result.boxes.xyxy[i].cpu().numpy()
            x1, y1, x2, y2 = box
            width = x2 - x1
            height = y2 - y1
            rect = plt.Rectangle((x1, y1), width, height,
                               fill=False, color='green', linewidth=2)
            ax3.add_patch(rect)

            # Draw segmentation mask
            mask = result.masks.data[i].cpu().numpy()
            mask = cv2.resize(mask.squeeze(), (img_width, img_height)) > CONFIDENCE_THRESHOLD
            color = np.random.random(3)
            image_masked = image.copy()
            image_masked[mask] = image_masked[mask] * 0.7 + color * 255 * 0.3
            ax3.imshow(image_masked)

            # Add label and confidence
            class_id = int(result.boxes.cls[i].item())
            class_name = yolov8_model.names[class_id]
            score = result.boxes.conf[i].item()
            ax3.text(x1, y1 - 5, f"{class_name}: {score:.2f}",
                    bbox=dict(facecolor='green', alpha=0.5),
                    fontsize=8, color='white')
    ax3.set_title('YOLOv8')

    plt.tight_layout()
    plt.show()

# %%
for img_id in img_ids[:3]:
    visualize_results(img_id, coco)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
